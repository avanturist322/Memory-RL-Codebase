# %%
import sys
sys.path.append("../../")

from environments.Memory_Maze.env.env_memory_maze import create_env

import matplotlib.pyplot as plt

# %%
env = create_env('memory_maze:MemoryMaze-9x9-v0', seed=42)
states = []
state = env.reset()

for t in range(3):
    
    state, reward, done, info = env.step(5)
    states.append(state)

env.close()

# %%
for img in states:
    plt.imshow(img)
    plt.show()
